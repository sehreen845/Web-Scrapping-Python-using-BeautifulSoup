# %%
import requests 
from bs4 import BeautifulSoup

# %%
web= requests.get("https://www.flipkart.com/search?q=mobiles%20under%2050000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off")

# %%
web.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(web.text,"lxml")
#print(soup)
# Out:
# <!DOCTYPE html>
# ...

# %%
np=soup.find("a",class_="_9QVEpD").get("href")
cnp = "https://www.flipkart.com"+np
print(cnp)
# Out:
# https://www.flipkart.com/search?q=mobiles+under+50000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=2
